# %%
import numpy as np
from Snippets import Snippets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from Variational_Autoencoder_alla_Valerio import VAE
import os
from tensorflow import keras

# %%
subfolder = "4.0_256"
model_name = "VAE_Vocals_128D_17388samples_20Epochs"
num = 500
path = os.path.join("data_and_models", subfolder, model_name + "_song_order" + str(num) + ".npy")
song_orders = np.load(path, allow_pickle=True)
print("Model was trained with " + str(len(song_orders)) + " Songs")
# Out:
# Model was trained with 361 Songs

# %% [markdown]
# We can normalise the data and denormalise it later

# %%
flattened_orders = np.asarray([item for order in song_orders for item in order])
old_min = flattened_orders.min()
old_max = flattened_orders.max()
print("The minimum value in song_orders is: " + str(old_min))
print("The maximum value in song_orders is: " + str(old_max))
# Out:
# The minimum value in song_orders is: -6.5055714
# The maximum value in song_orders is: 6.576535

# %%
norm_orders = Snippets._normalise(song_orders, 0, 1, old_min, old_max)

# %%
# # Add a end-token and the end of each song with value 0

# song_orders = []
# for song in norm_orders:
#     song = np.append(song, np.zeros(song.shape[1])).reshape(song.shape[0]+1, song.shape[1])
#     song_orders.append(song)

# %%
def generate_sequences(song_order, step: int, seq_length: int):
    X = []
    y = []
    for i in range(0, len(song_order) - seq_length, step):
        X.append(song_order[i:i+seq_length])
        y.append(song_order[i+seq_length])
    X = np.array(X)
    y = np.array(y)
    #y = y.reshape(y.shape[0], 1, y.shape[1])
    return X,y

# %%
x_data = []
y_data = []

for song in norm_orders:
    X_song, y_song = generate_sequences(song, step=1, seq_length=50)
    x_data.extend(X_song)
    y_data.extend(y_song)

x_data = np.array(x_data)
y_data = np.array(y_data)

print("X of one song: ", X_song.shape, "\ty of one song: ", y_song.shape)
print("X of all songs: ", x_data.shape, "\ty of all songs: ", y_data.shape)
# Out:
# X of one song:  (9, 50, 128) 	y of one song:  (9, 128)
# X of all songs:  (4783, 50, 128) 	y of all songs:  (4783, 128)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.1)

# %%
from tensorflow.keras.layers import Embedding, LSTM, Input, Dense, Dropout, Bidirectional
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError


# n_units = 256
# embedding_size = 150

# order_in = Input(shape=(x_train.shape[1], x_train.shape[2]))
# #x = Embedding(128, embedding_size,)(order_in)
# x = LSTM(n_units)(order_in)
# # x = layers.Dropout(0.2)(x)
# order_out = Dense(128, activation='softmax')(x)

# char_model = Model(order_in, order_out, name="char_rnn")

# char_model.compile(
#     # note that we use the same loss as with MNIST
#     # which is used when we want to learn a
#     # probability distribution
#     loss=MeanSquaredError,
#     optimizer=Adam(learning_rate=0.001)
# )

# char_model.summary()

# model = Sequential()
# model.add(LSTM((256), batch_input_shape=(None,None,128), return_sequences=True))
# model.add(LSTM((128), return_sequences=False))
# model.compile(loss='mean_squared_error', optimizer='Adam')

model = Sequential()
model.add(Bidirectional(LSTM((256), input_shape=(None,128), return_sequences=True, dropout=0.5)))
model.add(Bidirectional(LSTM(128, dropout=0.5)))
model.add(Dense(128))
#optimiser = keras.optimizers.Adam(learning_rate=0.0005)
model.compile(loss='mse', optimizer='rmsprop')
# Out:
# 2022-04-18 11:27:42.540345: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Epoch 28/30
# 4304/4304 [==============================] - 30s 7ms/sample - loss: 0.0033 - val_loss: 0.0034
# Epoch 29/30
# 4304/4304 [==============================] - 30s 7ms/sample - loss: 0.0033 - val_loss: 0.0032
# Epoch 30/30
# 4304/4304 [==============================] - 30s 7ms/sample - loss: 0.0033 - val_loss: 0.0026

# %%
path = os.path.join("data_and_models", subfolder, model_name + "_ML2_LTSM")
model.save(path)
# Out:
# 2022-04-18 11:43:41.631735: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: data_and_models/4.0_256/VAE_Vocals_128D_17388samples_20Epochs_ML2_LTSM/assets

# %%
short = x_test[0][:150]
results = model.predict(short.reshape(1,short.shape[0],short.shape[1]))
# Out:
# /Users/dearvr-Tester/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
np.mean(abs(Snippets._denormalise(results[0], 0, 1, old_min, old_max) - Snippets._denormalise(y_test[0], 0, 1, old_min, old_max)))
# Out:
# 0.49040106

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ## Test Reconstruction

# %%
#path = os.path.join("data_and_models", subfolder, model_name + "_ML2_LSTM")
#model = keras.models.load_model(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 path = os.path.join("data_and_models", subfolder, model_name + "_ML2_LTSM")
# ----> 2 model = keras.models.load_model(path)
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204       filepath = path_to_string(filepath)
#     205       if isinstance(filepath, str):
# --> 206         return saved_model_load.load(filepath, compile, options)
#     208 raise IOError(
#     209     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     210     'available) or SavedModel.')
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py:155, in load(path, compile, options)
#     152 loaded = tf_load.load_partial(path, nodes_to_load, options=options)
#     154 # Finalize the loaded layers and remove the extra tracked dependencies.
# --> 155 keras_loader.finalize_objects()
#     156 keras_loader.del_tracking()
#     158 model = loaded['root']
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py:626, in KerasObjectLoader.finalize_objects(self)
#     623 _finalize_config_layers(layers_revived_from_config)
#     625 # Initialize graph networks, now that layer dependencies have been resolved.
# --> 626 self._reconstruct_all_models()
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py:645, in KerasObjectLoader._reconstruct_all_models(self)
#     643   all_initialized_models.add(model_id)
#     644   model, layers = self.model_layer_dependencies[model_id]
# --> 645   self._reconstruct_model(model_id, model, layers)
#     646   _finalize_config_layers([model])
#     648 if all_initialized_models != set(self.model_layer_dependencies.keys()):
#     649   # This should not happen.
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py:686, in KerasObjectLoader._reconstruct_model(self, model_id, model, layers)
#     684 input_specs = self._infer_inputs(first_layer)
#     685 input_shapes = self._infer_inputs(first_layer, convert_to_shapes=True)
# --> 686 model._set_inputs(input_specs)  # pylint: disable=protected-access
#     687 if not model.built and not isinstance(input_specs, dict):
#     688   model.build(input_shapes)
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2619, in Model._set_inputs(self, inputs, outputs, training)
#    2593 """Set model's input and output specs based on the input data received.
#    2594
#    2595 This is to be used for Model subclasses, which do not know at instantiation
#    (...)
#    2616     first layer isn't FeatureLayer.
#    2617 """
#    2618 self._set_save_spec(inputs)
# -> 2619 inputs = self._set_input_attrs(inputs)
#    2621 if outputs is None:
#    2622   kwargs = {}
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py:522, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     520 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521 try:
# --> 522   result = method(self, *args, **kwargs)
#     523 finally:
#     524   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2658, in Model._set_input_attrs(self, inputs)
#    2656     input_shape = (None,)
#    2657   else:
# -> 2658     input_shape = (None,) + tuple(inputs.shape[1:])
#    2659   self._build_input_shape = input_shape
#    2661 # Cast inputs to the compute dtype. This is primarily used
#    2662 # when saving to determine the correct dtype in the input signature.
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
def generate_order(model, seed, target_length):
    needed_coordinates = target_length - len(seed)
    seed = seed.reshape(1,seed.shape[0],seed.shape[1])
    for i in range(needed_coordinates):
        next_coordinate = model.predict(seed)
        next_coordinate = next_coordinate.reshape(1, next_coordinate.shape[0], next_coordinate.shape[1])
        seed = np.append(seed, next_coordinate, axis=1)
        print(f"reconstructed {i+1} of {needed_coordinates} coordinates", end='\r')
    output_order = seed.reshape(seed.shape[1], seed.shape[2])
    return seed

# %%
original = song_orders[0]
seed = original[:4]
reconstructed = generate_order(model, seed, len(original))
# Out:
# reconstructed 30 of 30 coordinates

# %%
reconstructed = reconstructed.reshape(reconstructed.shape[1], reconstructed.shape[2])

# %%
# original = Snippets._denormalise(original, 0, 1, old_min, old_max)
#reconstructed = Snippets._denormalise(reconstructed, 0, 1, old_min, old_max)

# %%
print("This is the original")
plt.figure(figsize=(20,20))
plt.plot(original[:, 0], original[:, 1], '-.o', markersize=5, markerfacecolor='red')
plt.show()
# Out:
# This is the original

# %%
print("This is the reconstruction")
plt.figure(figsize=(20,20))
plt.plot(reconstructed[:, 0], reconstructed[:, 1], '-.o', markersize=5, markerfacecolor='red')
plt.show()
# Out:
# This is the reconstruction

# %%
WIN_LENGTH = 690*2
HOP_LENGTH = 690
N_FFT = 690*2

path = os.path.join("data_and_models", subfolder, model_name)
snippet_autoencoder = VAE.load(path)
# Out:
# WARNING:tensorflow:From /Users/dearvr-Tester/Documents/MetaHuman/venv/lib/python3.8/site-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
reconstructed_signal, reconstructed_spectos = Snippets.latent_representation_to_pcm(latent_representations=reconstructed,
                                                                                    model=snippet_autoencoder, 
                                                                                    hop_length=HOP_LENGTH, 
                                                                                    n_fft=N_FFT, 
                                                                                    win_length=WIN_LENGTH)

# %%
display(Audio(reconstructed_signal, rate=44100))

# %%
folder_path = os.path.join('demo_data', 'stems')
paths = librosa.util.find_files(folder_path, ext=['wav'])
original_song, _ = librosa.load(paths[song_num],sr=44100, mono=True)

print("This is the original song: \n")
display(Audio(original_song, rate=44100))
